# %%
import numpy as np
import cv2
import time

face_model = 'res10_300x300_ssd_iter_140000.caffemodel'
face_prototxt = 'deploy.prototxt.txt'
age_model = 'age_net.caffemodel'
age_prototxt = 'age_deploy.prototxt'
gender_model = 'gender_net.caffemodel'
gender_prototxt = 'gender_deploy.prototxt'

age_list = ['(0-2)', '(4-6)', '(8-12)', '(15-20)', '(25-32)', '(38-43)', '(48-53)', '(60-100)']
gender_list = ['Male','Female']

title_name = 'Age and Gender Recognition'
min_confidence = 0.5
recognition_count = 0
elapsed_time = 0
OUTPUT_SIZE = (300, 300)

detector = cv2.dnn.readNetFromCaffe(face_prototxt, face_model)
age_detector = cv2.dnn.readNetFromCaffe(age_prototxt, age_model)
gender_detector = cv2.dnn.readNetFromCaffe(gender_prototxt, gender_model)

    
def detectAndDisplay(image):
    start_time = time.time()
    (h, w) = image.shape[:2]

    
    imageBlob = cv2.dnn.blobFromImage(image, 1.0, OUTPUT_SIZE,
        (104.0, 177.0, 123.0), swapRB=False, crop=False)
    # 1.0->scale, (104.0, 177.0, 123.0)-> min subtraction

    detector.setInput(imageBlob)
    detections = detector.forward()  # 얼굴 인식 

    for i in range(0, detections.shape[2]):
        confidence = detections[0, 0, i, 2]

        if confidence > min_confidence:
            box = detections[0, 0, i, 3:7] * np.array([w, h, w, h])
            (startX, startY, endX, endY) = box.astype("int")

            face = image[startY:endY, startX:endX]
            (fH, fW) = face.shape[:2]

            face_blob = cv2.dnn.blobFromImage(face, 1.0, (227, 227),
                    (78.4263377603, 87.7689143744, 114.895847746),swapRB=False)
            
    
            age_detector.setInput(face_blob)
            age_predictions = age_detector.forward()
            age_index = age_predictions[0].argmax()
            age = age_list[age_index]
            age_confidence = age_predictions[0][age_index]
            
            gender_detector.setInput(face_blob)
            gender_predictions = gender_detector.forward()
            gender_index = gender_predictions[0].argmax()
            gender = gender_list[gender_index]
            gender_confidence = gender_predictions[0][gender_index]

            text = "{}: {:.2f}% {}: {:.2f}%".format(gender, gender_confidence*100, age, age_confidence*100)
            y = startY - 10 if startY - 10 > 10 else startY + 10
            #cv2.rectangle(image, (startX, startY), (endX, endY),
            #    (0, 255, 0), 2)
            face_image = cv2.GaussianBlur(face,(99,99), 30)
            frame[startY:endY, startX:endX] = face_image
            cv2.putText(image, text, (startX, y),
                cv2.FONT_HERSHEY_SIMPLEX, 0.45, (0, 255, 0), 2)
            print('==============================')
            print("Gender {} time {:.2f} %".format(gender, gender_confidence*100))
            print("Age {} time {:.2f} %".format(age, age_confidence*100))
            print("Age     Probability(%)")
            for i in range(len(age_list)):
                print("{}  {:.2f}%".format(age_list[i], age_predictions[0][i]*100))
                
            print("Gender  Probability(%)")
            for i in range(len(gender_list)):
                print("{}  {:.2f} %".format(gender_list[i], gender_predictions[0][i]*100))
                

                
    frame_time = time.time() - start_time
    global elapsed_time
    elapsed_time += frame_time
    print("Frame time {:.3f} seconds".format(frame_time))
    
    cv2.imshow(title_name, image)
    

vs = cv2.VideoCapture(0)
time.sleep(2.0)
if not vs.isOpened:
    print('### Error opening video ###')
    exit(0)
while True:
    ret, frame = vs.read()
    if frame is None:
        print('### No more frame ###')
        vs.release()
        break
    detectAndDisplay(frame)
    if cv2.waitKey(1) & 0xFF == ord('q'):
        break


vs.release()
cv2.destroyAllWindows()
# Out:
# ==============================
# Gender Male time 89.97 %
# Age (15-20) time 73.10 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.00%
# (8-12)
%
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.17%
# (8-12)  80.29%
# (15-20)  0.17%
# (25-32)  18.73%
# (38-43)  0.09%
# (48-53)  0.44%
# (60-100)  0.10%
# Gender  Probability(%)
# Male  67.59 %
# Female  32.41 %
# Frame time 0.089 seconds
# ==============================
# Gender Female time 62.15 %
# Age (25-32) time 49.59 %
# Age     Probability(%)
# (0-2)  0.03%
# (4-6)  0.32%
# (8-12)  47.07%
# (15-20)  0.53%
# (25-32)  49.59%
# (38-43)  0.37%
# (48-53)  1.68%
# (60-100)  0.42%
# Gender  Probability(%)
# Male  37.85 %
# Female  62.15 %
# Frame time 0.086 seconds
# ==============================
# Gender Male time 66.15 %
# Age (25-32) time 57.67 %
# Age     Probability(%)
# (0-2)  0.02%
# (4-6)  0.23%
# (8-12)  40.25%
# (15-20)  0.24%
# (25-32)  57.67%
# (38-43)  0.29%
# (48-53)  1.01%
# (60-100)  0.29%
# Gender  Probability(%)
# Male  66.15 %
# Female  33.85 %
# Frame time 0.085 seconds
# ==============================
# Gender Female time 78.32 %
# Age (8-12) time 64.29 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.12%
# (8-12)  64.29%
# (15-20)  0.19%
# (25-32)  34.49%
# (38-43)  0.15%
# (48-53)  0.63%
# (60-100)  0.12%
# Gender  Probability(%)
# Male  21.68 %
# Female  78.32 %
# Frame time 0.106 seconds
# ==============================
# Gender Female time 55.09 %
# Age (25-32) time 58.12 %
# Age     Probability(%)
# (0-2)  0.03%
# (4-6)  0.19%
# (8-12)  38.01%
# (15-20)  0.25%
# (25-32)  58.12%
# (38-43)  0.38%
# (48-53)  2.52%
# (60-100)  0.49%
# Gender  Probability(%)
# Male  44.91 %
# Female  55.09 %
# Frame time 0.102 seconds
# ==============================
# Gender Female time 61.83 %
# Age (8-12) time 86.26 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.05%
# (8-12)  86.26%
# (15-20)  0.08%
# (25-32)  13.42%
# (38-43)  0.04%
# (48-53)  0.12%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  38.17 %
# Female  61.83 %
# Frame time 0.110 seconds
# ==============================
# Gender Female time 50.04 %
# Age (8-12) time 84.99 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.13%
# (8-12)  84.99%
# (15-20)  0.08%
# (25-32)  14.61%
# (38-43)  0.04%
# (48-53)  0.13%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  49.96 %
# Female  50.04 %
# Frame time 0.115 seconds
# ==============================
# Gender Female time 80.58 %
# Age (8-12) time 89.47 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.08%
# (8-12)  89.47%
# (15-20)  0.06%
# (25-32)  10.29%
# (38-43)  0.02%
# (48-53)  0.07%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  19.42 %
# Female  80.58 %
# Frame time 0.116 seconds
# ==============================
# Gender Female time 55.23 %
# Age (8-12) time 88.93 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.10%
# (8-12)  88.93%
# (15-20)  0.06%
# (25-32)  10.74%
# (38-43)  0.03%
# (48-53)  0.12%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  44.77 %
# Female  55.23 %
# Frame time 0.109 seconds
# ==============================
# Gender Female time 77.38 %
# Age (8-12) time 95.52 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.06%
# (8-12)  95.52%
# (15-20)  0.05%
# (25-32)  4.27%
# (38-43)  0.03%
# (48-53)  0.08%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  22.62 %
# Female  77.38 %
# Frame time 0.100 seconds
# ==============================
# Gender Male time 54.74 %
# Age (8-12) time 88.28 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.04%
# (8-12)  88.28%
# (15-20)  0.05%
# (25-32)  11.55%
# (38-43)  0.02%
# (48-53)  0.06%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  54.74 %
# Female  45.26 %
# Frame time 0.092 seconds
# ==============================
# Gender Male time 86.73 %
# Age (25-32) time 55.77 %
# Age     Probability(%)
# (0-2)  0.06%
# (4-6)  0.87%
# (8-12)  40.39%
# (15-20)  0.54%
# (25-32)  55.77%
# (38-43)  0.52%
# (48-53)  1.31%
# (60-100)  0.53%
# Gender  Probability(%)
# Male  86.73 %
# Female  13.27 %
# Frame time 0.107 seconds
# ==============================
# Gender Male time 62.41 %
# Age (8-12) time 55.90 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.45%
# (8-12)  55.90%
# (15-20)  0.16%
# (25-32)  42.78%
# (38-43)  0.14%
# (48-53)  0.49%
# (60-100)  0.07%
# Gender  Probability(%)
# Male  62.41 %
# Female  37.59 %
# Frame time 0.107 seconds
# ==============================
# Gender Female time 58.99 %
# Age (8-12) time 91.95 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.09%
# (8-12)  91.95%
# (15-20)  0.04%
# (25-32)  7.85%
# (38-43)  0.02%
# (48-53)  0.04%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  41.01 %
# Female  58.99 %
# Frame time 0.099 seconds
# ==============================
# Gender Male time 54.57 %
# Age (8-12) time 90.34 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.46%
# (8-12)  90.34%
# (15-20)  0.06%
# (25-32)  8.93%
# (38-43)  0.04%
# (48-53)  0.15%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  54.57 %
# Female  45.43 %
# Frame time 0.090 seconds
# ==============================
# Gender Male time 63.88 %
# Age (8-12) time 94.12 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.12%
# (8-12)  94.12%
# (15-20)  0.04%
# (25-32)  5.64%
# (38-43)  0.02%
# (48-53)  0.05%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  63.88 %
# Female  36.12 %
# Frame time 0.084 seconds
# ==============================
# Gender Male time 76.77 %
# Age (8-12) time 79.26 %
# Age     Probability(%)
# (0-2)  0.03%
# (4-6)  1.09%
# (8-12)  79.26%
# (15-20)  0.21%
# (25-32)  18.38%
# (38-43)  0.17%
# (48-53)  0.73%
# (60-100)  0.13%
# Gender  Probability(%)
# Male  76.77 %
# Female  23.23 %
# Frame time 0.091 seconds
# ==============================
# Gender Female time 61.53 %
# Age (25-32) time 78.80 %
# Age     Probability(%)
# (0-2)  0.08%
# (4-6)  0.84%
# (8-12)  16.29%
# (15-20)  0.35%
# (25-32)  78.80%
# (38-43)  0.65%
# (48-53)  2.17%
# (60-100)  0.81%
# Gender  Probability(%)
# Male  38.47 %
# Female  61.53 %
# Frame time 0.090 seconds
# ==============================
# Gender Female time 55.88 %
# Age (8-12) time 95.23 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.25%
# (8-12)  95.23%
# (15-20)  0.04%
# (25-32)  4.42%
# (38-43)  0.01%
# (48-53)  0.04%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  44.12 %
# Female  55.88 %
# Frame time 0.101 seconds
# ==============================
# Gender Female time 70.49 %
# Age (8-12) time 91.82 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.28%
# (8-12)  91.82%
# (15-20)  0.05%
# (25-32)  7.75%
# (38-43)  0.02%
# (48-53)  0.06%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  29.51 %
# Female  70.49 %
# Frame time 0.092 seconds
# ==============================
# Gender Male time 54.65 %
# Age (8-12) time 89.83 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.24%
# (8-12)  89.83%
# (15-20)  0.07%
# (25-32)  9.75%
# (38-43)  0.03%
# (48-53)  0.06%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  54.65 %
# Female  45.35 %
# Frame time 0.094 seconds
# ==============================
# Gender Female time 58.68 %
# Age (8-12) time 88.14 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.14%
# (8-12)  88.14%
# (15-20)  0.07%
# (25-32)  11.55%
# (38-43)  0.03%
# (48-53)  0.06%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  41.32 %
# Female  58.68 %
# Frame time 0.085 seconds
# ==============================
# Gender Male time 63.84 %
# Age (8-12) time 92.04 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.12%
# (8-12)  92.04%
# (15-20)  0.06%
# (25-32)  7.70%
# (38-43)  0.02%
# (48-53)  0.05%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  63.84 %
# Female  36.16 %
# Frame time 0.105 seconds
# ==============================
# Gender Female time 75.27 %
# Age (8-12) time 91.93 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.09%
# (8-12)  91.93%
# (15-20)  0.09%
# (25-32)  7.78%
# (38-43)  0.02%
# (48-53)  0.08%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  24.73 %
# Female  75.27 %
# Frame time 0.089 seconds
# ==============================
# Gender Female time 55.32 %
# Age (8-12) time 97.09 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.13%
# (8-12)  97.09%
# (15-20)  0.04%
# (25-32)  2.69%
# (38-43)  0.01%
# (48-53)  0.04%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  44.68 %
# Female  55.32 %
# Frame time 0.086 seconds
# ==============================
# Gender Female time 68.06 %
# Age (8-12) time 98.32 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.09%
# (8-12)  98.32%
# (15-20)  0.04%
# (25-32)  1.52%
# (38-43)  0.01%
# (48-53)  0.03%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  31.94 %
# Female  68.06 %
# Frame time 0.095 seconds
# ==============================
# Gender Female time 63.89 %
# Age (8-12) time 91.04 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.42%
# (8-12)  91.04%
# (15-20)  0.10%
# (25-32)  8.09%
# (38-43)  0.04%
# (48-53)  0.29%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  36.11 %
# Female  63.89 %
# Frame time 0.102 seconds
# ==============================
# Gender Female time 74.13 %
# Age (8-12) time 97.38 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.08%
# (8-12)  97.38%
# (15-20)  0.03%
# (25-32)  2.46%
# (38-43)  0.01%
# (48-53)  0.04%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  25.87 %
# Female  74.13 %
# Frame time 0.094 seconds
# ==============================
# Gender Female time 67.49 %
# Age (8-12) time 88.80 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.12%
# (8-12)  88.80%
# (15-20)  0.11%
# (25-32)  10.73%
# (38-43)  0.03%
# (48-53)  0.19%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  32.51 %
# Female  67.49 %
# Frame time 0.094 seconds
# ==============================
# Gender Female time 74.44 %
# Age (8-12) time 93.33 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.23%
# (8-12)  93.33%
# (15-20)  0.09%
# (25-32)  6.16%
# (38-43)  0.02%
# (48-53)  0.14%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  25.56 %
# Female  74.44 %
# Frame time 0.086 seconds
# ==============================
# Gender Female time 78.35 %
# Age (8-12) time 87.04 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.23%
# (8-12)  87.04%
# (15-20)  0.08%
# (25-32)  12.38%
# (38-43)  0.04%
# (48-53)  0.21%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  21.65 %
# Female  78.35 %
# Frame time 0.090 seconds
# ==============================
# Gender Female time 65.62 %
# Age (8-12) time 88.98 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.33%
# (8-12)  88.98%
# (15-20)  0.09%
# (25-32)  10.40%
# (38-43)  0.04%
# (48-53)  0.14%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  34.38 %
# Female  65.62 %
# Frame time 0.085 seconds
# ==============================
# Gender Male time 64.76 %
# Age (8-12) time 77.44 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.09%
# (8-12)  77.44%
# (15-20)  0.09%
# (25-32)  22.05%
# (38-43)  0.05%
# (48-53)  0.26%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  64.76 %
# Female  35.24 %
# Frame time 0.105 seconds
# ==============================
# Gender Male time 73.36 %
# Age (8-12) time 55.21 %
# Age     Probability(%)
# (0-2)  0.06%
# (4-6)  2.14%
# (8-12)  55.21%
# (15-20)  0.27%
# (25-32)  39.07%
# (38-43)  0.38%
# (48-53)  2.48%
# (60-100)  0.39%
# Gender  Probability(%)
# Male  73.36 %
# Female  26.64 %
# Frame time 0.097 seconds
# ==============================
# Gender Male time 60.88 %
# Age (8-12) time 79.84 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.21%
# (8-12)  79.84%
# (15-20)  0.15%
# (25-32)  19.52%
# (38-43)  0.07%
# (48-53)  0.18%
# (60-100)  0.03%
# Gender  Probability(%)
# Male  60.88 %
# Female  39.12 %
# Frame time 0.088 seconds
# ==============================
# Gender Male time 74.09 %
# Age (8-12) time 83.34 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.31%
# (8-12)  83.34%
# (15-20)  0.14%
# (25-32)  15.90%
# (38-43)  0.06%
# (48-53)  0.22%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  74.09 %
# Female  25.91 %
# Frame time 0.087 seconds
# ==============================
# Gender Female time 75.64 %
# Age (8-12) time 92.13 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.53%
# (8-12)  92.13%
# (15-20)  0.07%
# (25-32)  7.16%
# (38-43)  0.04%
# (48-53)  0.06%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  24.36 %
# Female  75.64 %
# Frame time 0.255 seconds
# ==============================
# Gender Female time 51.59 %
# Age (8-12) time 84.18 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.35%
# (8-12)  84.18%
# (15-20)  0.04%
# (25-32)  15.37%
# (38-43)  0.02%
# (48-53)  0.03%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  48.41 %
# Female  51.59 %
# Frame time 0.258 seconds
# ==============================
# Gender Male time 90.98 %
# Age (8-12) time 85.08 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.59%
# (8-12)  85.08%
# (15-20)  0.06%
# (25-32)  14.13%
# (38-43)  0.05%
# (48-53)  0.07%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  90.98 %
# Female  9.02 %
# Frame time 0.121 seconds
# ==============================
# Gender Male time 51.08 %
# Age (8-12) time 63.59 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.88%
# (8-12)  63.59%
# (15-20)  0.08%
# (25-32)  35.09%
# (38-43)  0.11%
# (48-53)  0.20%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  51.08 %
# Female  48.92 %
# Frame time 0.130 seconds
# ==============================
# Gender Male time 61.87 %
# Age (8-12) time 72.13 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.50%
# (8-12)  72.13%
# (15-20)  0.08%
# (25-32)  26.95%
# (38-43)  0.13%
# (48-53)  0.18%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  61.87 %
# Female  38.13 %
# Frame time 0.112 seconds
# ==============================
# Gender Male time 78.90 %
# Age (8-12) time 71.50 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  0.35%
# (8-12)  71.50%
# (15-20)  0.08%
# (25-32)  27.77%
# (38-43)  0.12%
# (48-53)  0.16%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  78.90 %
# Female  21.10 %
# Frame time 0.097 seconds
# ==============================
# Gender Male time 86.69 %
# Age (8-12) time 92.08 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.73%
# (8-12)  92.08%
# (15-20)  0.07%
# (25-32)  7.01%
# (38-43)  0.05%
# (48-53)  0.03%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  86.69 %
# Female  13.31 %
# Frame time 0.096 seconds
# ==============================
# Gender Male time 90.91 %
# Age (8-12) time 99.13 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.32%
# (8-12)  99.13%
# (15-20)  0.03%
# (25-32)  0.51%
# (38-43)  0.01%
# (48-53)  0.00%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  90.91 %
# Female  9.09 %
# Frame time 0.107 seconds
# ==============================
# Gender Male time 96.37 %
# Age (8-12) time 86.02 %
# Age     Probability(%)
# (0-2)  0.02%
# (4-6)  12.80%
# (8-12)  86.02%
# (15-20)  0.04%
# (25-32)  0.99%
# (38-43)  0.11%
# (48-53)  0.01%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  96.37 %
# Female  3.63 %
# Frame time 0.091 seconds
# ==============================
# Gender Male time 88.69 %
# Age (8-12) time 54.12 %
# Age     Probability(%)
# (0-2)  0.08%
# (4-6)  44.69%
# (8-12)  54.12%
# (15-20)  0.03%
# (25-32)  0.89%
# (38-43)  0.16%
# (48-53)  0.02%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  88.69 %
# Female  11.31 %
# Frame time 0.096 seconds
# ==============================
# Gender Male time 90.40 %
# Age (8-12) time 87.23 %
# Age     Probability(%)
# (0-2)  0.06%
# (4-6)  8.57%
# (8-12)  87.23%
# (15-20)  0.05%
# (25-32)  3.00%
# (38-43)  0.93%
# (48-53)  0.12%
# (60-100)  0.04%
# Gender  Probability(%)
# Male  90.40 %
# Female  9.60 %
# Frame time 0.093 seconds
# ==============================
# Gender Male time 96.38 %
# Age (8-12) time 87.56 %
# Age     Probability(%)
# (0-2)  0.04%
# (4-6)  9.84%
# (8-12)  87.56%
# (15-20)  0.06%
# (25-32)  1.90%
# (38-43)  0.52%
# (48-53)  0.06%
# (60-100)  0.02%
# Gender  Probability(%)
# Male  96.38 %
# Female  3.62 %
# Frame time 0.085 seconds
# ==============================
# Gender Male time 80.69 %
# Age (8-12) time 51.65 %
# Age     Probability(%)
# (0-2)  0.09%
# (4-6)  42.39%
# (8-12)  51.65%
# (15-20)  0.07%
# (25-32)  5.58%
# (38-43)  0.18%
# (48-53)  0.04%
# (60-100)  0.01%
# Gender  Probability(%)
# Male  80.69 %
# Female  19.31 %
# Frame time 0.091 seconds
# ==============================
# Gender Male time 92.88 %
# Age (8-12) time 51.37 %
# Age     Probability(%)
# (0-2)  0.05%
# (4-6)  45.32%
# (8-12)  51.37%
# (15-20)  0.04%
# (25-32)  3.13%
# (38-43)  0.07%
# (48-53)  0.02%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  92.88 %
# Female  7.12 %
# Frame time 0.095 seconds
# ==============================
# Gender Male time 99.12 %
# Age (8-12) time 92.51 %
# Age     Probability(%)
# (0-2)  0.01%
# (4-6)  4.18%
# (8-12)  92.51%
# (15-20)  0.07%
# (25-32)  3.21%
# (38-43)  0.02%
# (48-53)  0.01%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  99.12 %
# Female  0.88 %
# Frame time 0.083 seconds
# ==============================
# Gender Male time 99.20 %
# Age (8-12) time 98.62 %
# Age     Probability(%)
# (0-2)  0.00%
# (4-6)  0.67%
# (8-12)  98.62%
# (15-20)  0.09%
# (25-32)  0.61%
# (38-43)  0.00%
# (48-53)  0.00%
# (60-100)  0.00%
# Gender  Probability(%)
# Male  99.20 %
# Female  0.80 %
# Frame time 0.082 seconds
